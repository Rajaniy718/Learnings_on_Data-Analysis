# %% [markdown]
# # Chp 6 : Data Loading, Storage and File formats

# %% [markdown]
# ### 6.1 : Reading and Writing in Text formats
#
# Pandas features a number of functions for reading tabular data as a DataFrame object.
#
# read_csv - Load delimited data from a file, URL, or file-like object; use comma as default delimiter
#
# read_excel - Read tabular data from an Excel XLS or XLSX file
#
# read_clipboard - Variation of read_csv that reads data from the clipboard; useful for converting tables from web pages
#
# read_html -	Read all tables found in the given HTML document
#
# read_json -	Read data from a JSON (JavaScript Object Notation) string representation, file, URL, or file-like object
#
# read_pickle - Read an object stored by pandas using the Python pickle format
#
# read_sql -	Read the results of a SQL query (using SQLAlchemy)
#
# read_sql_table - Read a whole SQL table (using SQLAlchemy); equivalent to using a query that selects everything in that table using read_sql

# %% [markdown]
# #### Read csv sample file, excel and from sql database, pickle for examples.

# %% [markdown]
# Because of how messy data in the real world can be, some of the data loading functions (especially pandas.read_csv) have accumulated a long list of optional arguments over time. It's normal to feel overwhelmed by the number of different parameters (pandas.read_csv has around 50). The online pandas documentation has many examples about how each of these works, so if you're struggling to read a particular file, there might be a similar enough example to help you find the right parameters.
#
# For example:
#
# While you could do some munging by hand, the fields here are separated by a variable amount of whitespace.
# In these cases, you can pass a regular expression as a delimiter for pandas.read_csv.
# This can be expressed by the regular expression \s+, so we have then:
#
# pd.read_csv('file_name' , sep = '\s+')
#
# In the below example, the variables are separated by tab, hence the delimeter is '\t'.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo1 = pd.read_csv(url, sep = '\t')

# %%
chipo1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo2 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
chipo2.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# #### Reading Text Files in Pieces
# When processing very large files or figuring out the right set of arguments to correctly process a large file, you may want to read only a small piece of a file or iterate through smaller chunks of the file.
#
# Before we look at a large file, we make the pandas display settings more compact:

# %%
pd.options.display.max_rows = 10

# %% [markdown]
# If you want to read only a small number of rows (avoiding reading the entire file), specify that with nrows:

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv'
euro12 = pd.read_csv(url, nrows = 5)
euro12
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 0                     0  ...          13                 81.3%         41
# 1                     0  ...           9                 60.1%         53
# 2                     0  ...          10                 66.7%         25
# 3                     0  ...          22                 88.1%         43
# 4                     0  ...           6                 54.6%         36
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 0             62         2             9          0        9         9
# 1             73         8             7          0       11        11
# 2             38         8             4          0        7         7
# 3             45         6             5          0       11        11
# 4             51         5             6          0       11        11
#
#    Players Used
# 0            16
# 1            19
# 2            15
# 3            16
# 4            19
#
# [5 rows x 35 columns]

# %% [markdown]
# #### Writing Data to Text Format
#
# Data can also be exported to a delimited format.Using DataFrame’s to_csv method, we can write the data out to a comma-separated file: ????

# %%
euro12.to_csv("euro12.csv")

# %% [markdown]
# ##### JSON Data
#
# JSON (short for JavaScript Object Notation) has become one of the standard formats for sending data by HTTP request between web browsers and other applications.
#
# To convert a JSON string to Python form, use json.loads.
#
# json.dumps, on the other hand converts a Python object back to JSON.
#
# Need to export data from pandas to JSON, one way is to use the to_json methods on Series and DataFrame.

# %%
obj = """
{"name": "Wes",
 "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]},
              {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]
}
"""

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'cities_lived': ['Akron', 'Nashville', 'New York', 'San Francisco'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 34, 'hobbies': ['guitars', 'soccer']},
#   {'name': 'Katie', 'age': 42, 'hobbies': ['diving', 'art']}]}

# %%
asjson = json.dumps(result)
asjson
# Out:
# '{"name": "Wes", "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"], "pet": null, "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]}, {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]}'

# %%
data.to_json(sys.stdout)

# %% [markdown]
# #### XML and HTML: Web Scraping
#
# Pandas has a built-in function, pandas.read_html, which uses all of these libraries to automatically parse tables out of HTML files as DataFrame objects.
# To show how this works, I downloaded an HTML file (used in the pandas documentation) from the US FDIC showing bank failures.1 First, you must install some additional libraries used by read_html:

# %%
import pandas as pd

# %%
# tables = pd.read_html("listofgroupcompanyname.htm")
mf_tables = pd.read_html("https://www.sebi.gov.in/sebi_data/statistics/XBRL/MFTaxonomy.html")
len(tables)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       1 # tables = pd.read_html("listofgroupcompanyname.htm")
# ----> 2 mf_tables = pd.read_html("https://www.sebi.gov.in/sebi_data/statistics/XBRL/MFTaxonomy.html")
#       3 len(tables)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:915, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913 retained = None
#     914 for flav in flavor:
# --> 915     parser = _parser_dispatch(flav)
#     916     p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918     try:
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:864, in _parser_dispatch(flavor)
#     862 if flavor in ("bs4", "html5lib"):
#     863     if not _HAS_HTML5LIB:
# --> 864         raise ImportError("html5lib not found, please install it")
#     865     if not _HAS_BS4:
#     866         raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %%
https://groww.in/blog-sitemap.xml

# %% [markdown]
# ### 6.2 Binary Data formats
#
# One simple way to store (or serialize) data in binary format is using Python’s built-in pickle module. pandas objects all have a to_pickle method that writes the data to disk in pickle format:
#
#
# ### I encourage you to explore different file formats to see how fast they are and how well they work for your analysis.

# %%
frame.to_pickle("examples/frame_pickle")

# %% [markdown]
# Pickle files are in general readable only in Python. You can read any "pickled" object stored in a file by using the built-in pickle directly, or even more conveniently using pandas.read_pickle:

# %%
pd.read_pickle("examples/frame_pickle")

# %% [markdown]
# #### Reading Microsoft Excel Files
#
# Pandas also supports reading tabular data stored in Excel 2003 (and higher) files using either the pandas.ExcelFile class or pandas.read_excel function
#
# If you are reading multiple sheets in a file, then it is faster to create the pandas.ExcelFile, but you can also simply pass the filename to pandas.read_excel:

# %%
frame = pd.read_exel("examples/ex1.xlsx", sheet_name="Sheet1")

# %% [markdown]
# To write pandas data to Excel format, you must first create an ExcelWriter, then write data to it using the pandas
# object's to_excel method:

# %%
writer = pd.ExcelWriter("examples/ex2.xlsx")
frame.to_excel(writer, "Sheet1")
writer.close()

# %% [markdown]
# You can also pass a file path to to_excel and avoid the ExcelWriter:

# %%
frame.to_excel("examples/ex2.xlsx")

# %% [markdown]
# ### 6.3 : Interacting with Web APIs
#
# There are a number of ways to access these APIs from Python.One method that the author recommend is the requests package, which can be installed with pip or conda:
# ##### conda install requests
#
# API Scrapping

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://www.amfiindia.com/listofgroupcompanynames'
page = requests.get(url)
soup = BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title></title>
# <meta content="" name="keywords"/>
# <meta content="" name="description"/>
# <title>AMFI</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="index, follow" id="robots" name="robots"/>
# <link href="/Themes/Theme1/css/960_grid.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Theme1/css/jquery.fancybox.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Theme1/css/global.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Theme1/css/jquery.simplyscroll.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Theme1/css/jqtransform.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Theme1/css/responsive_style.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Theme1/scripts/colorbox/colorbox.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Theme1/css/thickbox.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Theme1/css/slick.css" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
#         <script language="JavaScript" src="/Themes/Theme1/scripts/html5.js" type="text/javascript"></script>
#         <script language="JavaScript" src="/Themes/Theme1/scripts/css3_mq.js" type="text/javascript"></script>
# 	<![endif]-->
# <script language="JavaScript" src="/Themes/Theme1/scripts/jquery-1.8.2.min.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/ufo.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/css_browser_selector.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/jquery.simplyscroll.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/jquery.backstretch.min.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/jquery.jqtransform.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/colorbox/jquery.colorbox-min.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/thickbox.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/jquery.fancybox.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/slick.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/common.js" type="text/javascript"></script>
# <link href="/Content/stylesheets/datepicker.css" rel="stylesheet" type="text/css"/>
# <script src="/Scripts/bootstrap-datepicker.js" type="text/javascript"></script>
# <script language="JavaScript" src="/Themes/Theme1/scripts/auto-complete.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	  var _gaq = _gaq || [];
# 	  _gaq.push(['_setAccount', 'UA-21257044-1']);
# 	  _gaq.push(['_trackPageview']);
#
# 	  (function() {
# 	    var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 	    ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	    var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
#
# 	</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-KWJ86PXK65"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag() { dataLayer.push(arguments); }
#     gtag('js', new Date());
#
#    // gtag('config', 'G-KWJ86PXK65');
#     gtag('config', 'KWJ86PXK65', { cookie_flags: 'SameSite=None;Secure' });
# </script>
# <script src="/Scripts/jquery.unobtrusive-ajax.min.js" type="text/javascript"></script>
# <script>
#         $(document).ready(function () {
#             $('.partialcontents').each(function (index, item) {
#                 var url = $(item).data('url');
#
#                 if (url.length > 0) {
#                     $(item).load(url);
#                 }
#             });
#         });
#     </script>
# <!-- Facebook Pixel Code -->
# <!-- End Facebook Pixel Code -->
# </head>
# <body>
# <header>
# <div class="hd-wrap">
# <div class="logo">
# <a href="/"><img alt="Association of Mutual Funds in India" height="61" src="/Themes/Theme1/images/logo.png" title="Association of Mutual Funds in India" width="229"/></a>
# </div>
# <nav>
# <ul class="top-nav">
# <li class="'first'"><a href="/press_release">Press Release</a></li>
# <li><a href="/aboutamfi">Know about AMFI</a></li>
# <li><a href="/useful-links">Useful Links</a></li>
# <li><a href="/contact-us">Contact Us</a></li>
# <li><a href="/careers">Careers</a></li>
# <li class="'last'"><a href="/kyc">KYC</a></li>
# </ul>
# <a class="sprite-new home" href="/" title="Home">Home</a>
# <div class="search-box">
# <form action="/searchresult" method="post">
# <input class="serch-lft" id="search" name="search" onblur="if(this.value=='') this.value='Search'" onfocus="if(this.value=='Search') this.value='';" type="text" value="Search"/>
# <input class="serchbox-rgt" type="submit" value=""/>
# </form>
# </div>
# <div class="top-navigate">
# <form action="/listofgroupcompanynames" method="post"> <ul>
# <li><a class="tp-main" href="javascript:;">Take me to...</a>
# <ul class="sub">
# <li><a href="/investor-corner/"> Investor Corner</a></li>
# <li><a href="/distributor-corner">Distributor Corner</a></li>
# <li><a href="/research-information">Research &amp; Information</a></li>
# </ul>
# </li>
# </ul>
# </form>
# </div>
# <a class="sprite-new rss mtop10" href="/rss-feeds"> </a>
# <br/>
# </nav>
# </div>
# <div class="clr"></div>
# </header>
# <script>
# 	$(document).ready(function(){
# 		$('.top-nav li:nth-child(2)').find('a').attr('target','_blank');
# 	});
# 	</script>
# <div class="clr"></div>
# <div class="container_12">
# <!-- Mobile -->
# <div class="mbl-hme-wrapper">
# <div class="top-navigate">
# <form action="/listofgroupcompanynames" method="post"> <ul>
# <li><a class="tp-main" href="javascript:;">Take me to...</a>
# <ul class="sub">
# <li><a href="/investor-corner">New to Mutual Funds</a></li>
# <li><a href="/investor-corner">Already an MF Investor</a></li>
# <li><a href="/distributor-corner">Intermediary</a></li>
# <li><a href="/research-information">Research &amp; Information</a></li>
# </ul>
# </li>
# </ul>
# </form>
# </div>
# </div>
# <!-- // -->
# <div class="clr"></div>
# <div id="lightbx-overlay"> </div>
# <div class="cont" id="sknt-form" style="padding-left:10px">
# <p style=""><a class="close" href="#sknt-form" style="color:#fff;text-decoration:none"><img alt="" src="/Themes/Theme1/images/close.png"/></a></p>
# <h1>World Investor Week Nov 22-28, 2021</h1>
# <h1>Message from Chairman, SEBI</h1>
# <div class="sknt-form">
# <table border="0" cellpadding="0" cellspacing="0" id="tblSavingForm">
# <tr>
# <td class="txt-lft" width="100%"><label class="label-important"><a href="https://www.sebi.gov.in/sebi_data/commondocs/nov-2021/chm-msg-eng.pdf" target="_blank">Message from Shri Ajay Tyagi, Chairman, SEBI, on the occasion of World Investor Week - 2021</a></label><br/><br/><br/>
# <label class="label-important"><a href="https://www.sebi.gov.in/sebi_data/commondocs/nov-2021/chm-msg-hin.pdf" target="_blank">विश्व निवेशक सप्ताह 202। के अवसर पर सेबी के अध्यक्ष श्री अजय त्यागी का संदेश</a></label>
# </td>
# </tr>
# </table>
# </div>
# <div class="clr"></div>
# </div>
# <div data-mercury="full" id="CenterContent">
# <div class="common-content" style="width: 100%;"> <div class="tab_container"> <div style="display: block;"><br/> <h2><b>List of all Group Companies  </b> [Updated up to 31-Aug-2024]<br/></h2><h4>(Pursuant to SEBI circular no. SEBI/HO/IMD/DF2/CIR/P/2019/152 dated 10-Dec-2019)</h4><a href="/Themes/Theme1/downloads/EmpiricalListofGroupCompanieswithGIN.xlsx"><img alt="Excel" src="/Images/excel.png"/></a> <a href="/Themes/Theme1/downloads/EmpiricalListofGroupCompanieswithGIN.pdf" target="_blank"><img alt="PDF" src="/Images/pdf.png"/></a> <table style="background-color: white; width: 100%; float: none;"> <tbody><tr style="background-color: rgb(240, 240, 240);"><th>Name of the Company </th><th>CIN</th><th>Equity ISIN</th><th>Name of the Group </th><th>Group Identification Number (GIN) </th><th>Sector</th><th>Classification Type</th> </tr><tr style="background-color: rgb(240, 240, 240);"><td>Bajaj Finance Limited</td><td>L65910MH1987PLC042961</td><td>INE296A01024</td><td>Rahul Bajaj Group</td><td>RAHULBAJAJGR-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Small Industries Development Bank of India</td><td></td><td></td><td>Small Industries Development Bank of India</td><td>SMALLINDUSTR-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Jamnagar Utilities and Power Private Limited</td><td>U40100GJ1991PTC051130</td><td></td><td>Mukesh Ambani Group</td><td>MUKESHAMBANI-01</td><td>Power</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Rural Electrification Corporation Limited</td><td>L40101DL1969GOI005095</td><td>INE020B01018</td><td>Power Finance Corporation Limited</td><td>POWERFINANCE-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>National Bank For Agriculture and Rural Development</td><td></td><td></td><td>National Bank For Agriculture and Rural Development</td><td>NATIONALBANK-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Power Finance Corporation Limited</td><td>L65910DL1986GOI024862</td><td>INE134E01011</td><td>Power Finance Corporation Limited</td><td>POWERFINANCE-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>HDFC Bank Limited</td><td>L65920MH1994PLC080618</td><td>INE040A01034</td><td>HDFC Bank Limited</td><td>HDFCBANKLIMI-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td
# <p class="fl"><a href="/terms-of-use">TERMS OF USE</a> | <a href="/privacy-notice">PRIVACY NOTICE</a></p>
# <p class="fr">© 2022 AMFI. All Rights Reserved</p>
# <div class="clr" style="line-height:0"> </div>
# </div>
# <!--<script type="text/javascript">var switchTo5x=false;</script>
# <script type="text/javascript" src="http://w.sharethis.com/button/buttons.js"></script>
# <script type="text/javascript">stLight.options({publisher: "67c58512-b0c9-4242-b5b2-c26125eccfce", doNotHash: false, doNotCopy: false, hashAddressBar: false});</script>-->
# <script type="text/javascript">
#         $(document).ready(function () {
# 		var windowWidth = $(window).width();
# 		if(windowWidth > 600){
# 			 $.backstretch("/Themes/Theme1/images/bg-inner.jpg");
# 		}
#         });
#     </script>
# <script type="text/javascript">
#             var FO = { movie: "/Themes/Theme1/flash/fundoo para.swf", width: "177", height: "345", majorversion: "8", build: "0", xi: "true", wmode: "transparent" };
#             UFO.create(FO, "flash-background");
#         </script>
# </footer>
# <sc>
# </sc></body></html>

# %%
mf_table = soup.find_all('table')[1]
mf_table
# Out:
# <table style="background-color: white; width: 100%; float: none;"> <tbody><tr style="background-color: rgb(240, 240, 240);"><th>Name of the Company </th><th>CIN</th><th>Equity ISIN</th><th>Name of the Group </th><th>Group Identification Number (GIN) </th><th>Sector</th><th>Classification Type</th> </tr><tr style="background-color: rgb(240, 240, 240);"><td>Bajaj Finance Limited</td><td>L65910MH1987PLC042961</td><td>INE296A01024</td><td>Rahul Bajaj Group</td><td>RAHULBAJAJGR-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Small Industries Development Bank of India</td><td></td><td></td><td>Small Industries Development Bank of India</td><td>SMALLINDUSTR-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Jamnagar Utilities and Power Private Limited</td><td>U40100GJ1991PTC051130</td><td></td><td>Mukesh Ambani Group</td><td>MUKESHAMBANI-01</td><td>Power</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Rural Electrification Corporation Limited</td><td>L40101DL1969GOI005095</td><td>INE020B01018</td><td>Power Finance Corporation Limited</td><td>POWERFINANCE-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>National Bank For Agriculture and Rural Development</td><td></td><td></td><td>National Bank For Agriculture and Rural Development</td><td>NATIONALBANK-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Power Finance Corporation Limited</td><td>L65910DL1986GOI024862</td><td>INE134E01011</td><td>Power Finance Corporation Limited</td><td>POWERFINANCE-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>HDFC Bank Limited</td><td>L65920MH1994PLC080618</td><td>INE040A01034</td><td>HDFC Bank Limited</td><td>HDFCBANKLIMI-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>LIC Housing Finance Limited</td><td>L65922MH1989PLC052257</td><td>INE115A01026</td><td>LIFE INSURANCE CORPORATION OF INDIA	</td><td>LIFEINSURANC-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>HDB Financial Services Limited</td><td>U65993GJ2007PLC051028</td><td></td><td>HDFC Bank Limited</td><td>HDFCBANKLIMI-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Muthoot Finance Limited</td><td>L65910KL1997PLC011300</td><td>INE414G01012</td><td>Muthoot Group</td><td>MUTHOOTGROUP-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Sikka Ports &amp; Terminals Limited</td><td>U45102GJ1997PLC031906</td><td></td><td>Mukesh Ambani Group</td><td>MUKESHAMBANI-01</td><td>Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Mindspace Business Parks REIT (Mindspace REIT)</td><td></td><td></td><td>Mindspace Business Parks Reit</td><td>MINDSPACEBUS-01</td><td>Realty</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Punjab National Bank</td><td></td><td>INE160A01022</td><td>Punjab National Bank </td><td>PUNJABNATION-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Axis Bank Ltd.</td><td>L65110GJ1993PLC020769	</td><td>INE238A01034</td><td>Axis Bank Limited</td><td>AXISBANKLIMI-01</td><td>Financial Services</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td
td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Larsen and Toubro Limited</td><td>L99999MH1946PLC004768</td><td>INE018A01030</td><td>Larsen And Toubro Limited</td><td>LARSENANDTOU-01</td><td>Construction</td><td>NSE</td></tr><tr style="background-color: rgb(240, 240, 240);"><td>Cholamandalam Investment ...

# %%
mf_titles = mf_table.find_all('th')
mf_titles
# Out:
# [<th>Name of the Company </th>,
#  <th>CIN</th>,
#  <th>Equity ISIN</th>,
#  <th>Name of the Group </th>,
#  <th>Group Identification Number (GIN) </th>,
#  <th>Sector</th>,
#  <th>Classification Type</th>]

# %%
mf_table_titles = [title.text.strip() for title in mf_titles]
print(mf_table_titles)
# Out:
# ['Name of the Company', 'CIN', 'Equity ISIN', 'Name of the Group', 'Group Identification Number (GIN)', 'Sector', 'Classification Type']

# %%
mf_df = pd.DataFrame(columns = mf_table_titles)
mf_df
# Out:
# Empty DataFrame
# Columns: [Name of the Company, CIN, Equity ISIN, Name of the Group, Group Identification Number (GIN), Sector, Classification Type]
# Index: []

# %%
mf_column_data = mf_table.find_all('tr')

# %%
for row in mf_column_data[1:]:
    mf_row_data = row.find_all('td')
    mf_individual_row = [data.text.strip() for data in mf_row_data]
#     print(mf_individual_row)

    mf_length = len(mf_df)
    mf_df.loc[mf_length] = mf_individual_row

# %%
mf_df
# Out:
#                                    Name of the Company                    CIN  \
# 0                                Bajaj Finance Limited  L65910MH1987PLC042961
# 1           Small Industries Development Bank of India
# 2         Jamnagar Utilities and Power Private Limited  U40100GJ1991PTC051130
# 3            Rural Electrification Corporation Limited  L40101DL1969GOI005095
# 4    National Bank For Agriculture and Rural Develo...
# ..                                                 ...                    ...
# 389             Avaada Solarise Energy Private Limited  U40300DL2018PTC338280
# 390                    Avaada SataraMH Private Limited  U40100UP2019PTC124019
# 391                   Fermi Solarfarms Private Limited  U40106DL2013FTC248848
# 392           Clean Sustainable Energy Private Limited  U40300MH2013PTC248435
# 393                          India Universal Trust AL1
#
#       Equity ISIN                                  Name of the Group  \
# 0    INE296A01024                                  Rahul Bajaj Group
# 1                         Small Industries Development Bank of India
# 2                                                Mukesh Ambani Group
# 3    INE020B01018                  Power Finance Corporation Limited
# 4                  National Bank For Agriculture and Rural Develo...
# ..            ...                                                ...
# 389                                          Avaada restricted Group
# 390                                          Avaada restricted Group
# 391                                          Avaada restricted Group
# 392                                          Avaada restricted Group
# 393                                        India Universal Trust AL1
#
#     Group Identification Number (GIN)              Sector Classification Type
# 0                     RAHULBAJAJGR-01  Financial Services                 NSE
# 1                     SMALLINDUSTR-01  Financial Services                 NSE
# 2                     MUKESHAMBANI-01               Power                 NSE
# 3                     POWERFINANCE-01  Financial Services                 NSE
# 4                     NATIONALBANK-01  Financial Services                 NSE
# ..                                ...                 ...                 ...
# 389                   AVAADARESTRI-01           Utilities       CRISIL - GICS
# 390                   AVAADARESTRI-01           Utilities       CRISIL - GICS
# 391                   AVAADARESTRI-01           Utilities       CRISIL - GICS
# 392                   AVAADARESTRI-01           Utilities       CRISIL - GICS
# 393                   INDIAUNIVERS-01  Financial Services                 NSE
#
# [394 rows x 7 columns]
